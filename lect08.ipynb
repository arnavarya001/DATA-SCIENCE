# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavarya001/DATA-SCIENCE/blob/main/lect08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# OOPs

# %%
class mirai:
  strength = 100
  teacher = ['A','B','C']
  div = ['alpha','beta']
  sub = ['ds','dev','dsa']

  def __init__(self):
    print('helo bro')



obj = mirai()
print(obj.strength)
print(obj.teacher)
print(obj.div)
print(obj.sub)
# Out:
# helo bro
# 100
# ['A', 'B', 'C']
# ['alpha', 'beta']
# ['ds', 'dev', 'dsa']

# %%
# Constructor (__init__)

# Automatically called when an object is created.
class student:
  def __init__(self,name,age):
    self.name = name
    self.age = age

a = student('Jhon',20)
print(a.name)
print(a.age)
# Out:
# Jhon
# 20

# %%
# without Constructor (__init__) using function
class student:
  def define(self,name,age):
    self.name = name
    self.age = age

a = student()
a.define('Jhon',20)
print(a.name)
print(a.age)
# Out:
# Jhon
# 20

# %%
# Encapsulation

# Wrapping data and methods together.
class student:
  def __init__(self,name,age):
    self.name = name
    self.age = age
  def display(self):
    print('Name:',self.name)
    print('Age:',self.age)

a = student('Jhon',20)
a.display()
# Out:
# Name: Jhon
# Age: 20

# %%
# from top import student
# a= student("Jhon",20)
# a.display()

# %%
# class person:
#     def __init__(self,h,w,age):
#         self.height = h
#         self.height = w
#         self.age = age
# class Rahul(person):
#     def __init__(self,g,name,b,h,w,age):

#         super().__init__(h,w,age)
#         self.gender = g
#         self.name = name
#         self.bank_balance = b

# obj = Rahul("male","rahul",100,5,55,18)
# a = person(20,55,20)
# print(obj.age)

# %%
# distractor,inhertance,vertiual poly.....(hw)

# %%
# Polymorphism
# Same method, different behavior.

class Dog:
    def sound(self):
        print("Bark")

class Cat:
    def sound(self):
        print("Meow")

for animal in [Dog(), Cat()]:
    animal.sound()

# %%
# def sum(a,b):
#     return a+b;
# def sum(a,b,c):
#     return a+b+c;
# a = sum(2,3)
# b = sum(2,3,4)
# print(a)
# print(b).   not possible

# %%
class complex:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def __add__(self, other):
        # return complex(self.x + other.x, self.y + other.y)
        a = self.x + other.x
        b= self.y + other.y

        result = complex(a,b)
        return result

    def display(self):
        print(self.x,'+i',self.y)
a = complex(2,3)
b = complex(4,5)
c = a+b
c.display()
