# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavarya001/DATA-SCIENCE/blob/main/lect005.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dct = {
    'name':['tom','nick','krish','jack'],
    'age':[20,21,19,18],
    'roll': [1,2,3,4]
}

df = pd.DataFrame(dct,index=['a','b','c','d'])
# print(df)
display(df)   #use display for printing dataframe
# Out:
#     name  age  roll
# a    tom   20     1
# b   nick   21     2
# c  krish   19     3
# d   jack   18     4

# %%
# Viewing Data
# df.head()      # First 5 rows
# df.tail()      # Last 5 rows
# df.info()      # Information about DataFrame
# df.describe()  # Statistical summary

# Selecting Data
# df["Name"]          # Select column
# df.loc[0]           # Select row by label
# df.iloc[0]          # Select row by index

# Filtering Data
# df[df["Marks"] > 80]

# Sorting Data
# df.sort_values("Marks")
# df.sort_values("Marks", ascending=False)

# Handling Missing Values
# df.isnull()
# df.dropna()
# df.fillna(0)

# Adding a Column
# df["Grade"] = ["A", "B"]

# Deleting a Column
# df.drop("Grade", axis=1)

# Grouping Data
# df.groupby("Department").mean()

# Merging DataFrames
# pd.merge(df1, df2, on="ID")

# Renaming Columns
# df.rename(columns={"Marks": "Score"})

# Finding Statistics
# df["Marks"].mean()
# df["Marks"].sum()
# df["Marks"].max()
# df["Marks"].min()
# df["Marks"].count()

# Saving Data
# df.to_csv("output.csv")
# df.to_excel("output.xlsx")

# %%
import pandas as pd

df=pd.read_csv('student_data.csv')
# display(df)
df.tail(3)
df.info()
df.describe()
df.columns
df.index
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   study_hours            10000 non-null  int64
#  1   attendance             10000 non-null  int64
#  2   sleep_hours            10000 non-null  int64
#  3   internet_usage         10000 non-null  int64
#  4   assignments_completed  10000 non-null  int64
#  5   previous_score         10000 non-null  int64
#  6   exam_score             10000 non-null  float64
#  7   placement_status       10000 non-null  object
# dtypes: float64(1), int64(6), object(1)
# memory usage: 625.1+ KB
# RangeIndex(start=0, stop=10000, step=1)

# %%
df=pd.read_csv('student_data.csv')

df[['study_hours','internet_usage']]

# df.study_hours    #dont use
df.iloc[0:6]    #index
df.loc[df['study_hours']== 11,['study_hours','sleep_hours']].iloc[4: 8]

df.loc[4]
# Out:
# study_hours                   5
# attendance                   52
# sleep_hours                   8
# internet_usage                6
# assignments_completed         8
# previous_score               40
# exam_score                78.82
# placement_status         Placed
# Name: 4, dtype: object

# %%
df=pd.read_csv('student_data.csv')
df.loc[df['assignments_completed']==8].iloc[1]

# %%
df=pd.read_csv('student_data.csv')
# df[df['assignments_completed']>3]

#rename columns
df.rename(columns ={'assignments_completed':'assign_completed'},inplace =True)
df
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
df=pd.read_csv('student_data.csv')
df.drop('attendance',axis=1, inplace=True)
df.dropna(inplace=True)
df
# Out:
#       study_hours  sleep_hours  internet_usage  assignments_completed  \
# 0               7            8               7                     10
# 1               4            5               3                      8
# 2              11            7               6                     10
# 3               8            9               8                      4
# 4               5            8               6                      8
# ...           ...          ...             ...                    ...
# 9995            2            9               7                      8
# 9996            7            6               9                      4
# 9997           10            8               5                     10
# 9998           10            7               5                      8
# 9999            2            6              11                     16
#
#       previous_score  exam_score placement_status
# 0                 62      100.00           Placed
# ...

# %% [markdown]
# how to use lamda function

# %%
# Import pandas library
import pandas as pd

# Create a Series
pd.Series()

# Create a DataFrame
pd.DataFrame()

# Read data from a CSV file
pd.read_csv()

# Read data from an Excel file
pd.read_excel()

# Read data from a JSON file
pd.read_json()

# Display the first 5 rows
df.head()

# Display the last 5 rows
df.tail()

# Show DataFrame information (columns, types, null values)
df.info()

# Generate statistical summary
df.describe()

# Return DataFrame dimensions (rows, columns)
df.shape

# Display column names
df.columns

# Display row index labels
df.index

# Select a column
df["column_name"]

# Select rows/columns by label
df.loc[]

# Select rows/columns by integer position
df.iloc[]

# Filter rows based on a condition
df[df["Age"] > 25]

# Add or update a column
df["new_column"] = values

# Rename columns
df.rename()

# Remove rows or columns
df.drop()

# Sort values by column
df.sort_values()

# Check for missing values
df.isnull()

# Check for non-missing values
df.notnull()

# Count missing values
df.isnull().sum()

# Replace missing values
df.fillna()

# Remove missing values
df.dropna()

# Replace specific values
df.replace()

# Find unique values
df.unique()

# Count unique values
df.nunique()

# Group data and aggregate
df.groupby()

# Aggregate multiple statistics
df.agg()

# Apply a function to values
df.apply()

# Apply function element-wise
df.map()

# Merge DataFrames (SQL-style join)
pd.merge()

# Concatenate DataFrames
pd.concat()

# Join DataFrames using index
df.join()

# Create a pivot table
df.pivot_table()

# Reshape data from wide to long
pd.melt()

# Convert column to datetime
pd.to_datetime()

# Extract year from datetime
df["date"].dt.year

# Extract month from datetime
df["date"].dt.month

# Extract day from datetime
df["date"].dt.day

# Calculate sum
df.sum()

# Calculate mean
df.mean()

# Calculate median
df.median()

# Find minimum value
df.min()

# Find maximum value
df.max()

# Count non-null values
df.count()

# Calculate standard deviation
df.std()

# Calculate variance
df.var()

# Calculate correlation
df.corr()

# Get cumulative sum
df.cumsum()

# Get cumulative maximum
df.cummax()

# Get cumulative minimum
df.cummin()

# Remove duplicate rows
df.drop_duplicates()

# Check duplicated rows
df.duplicated()

# Sample random rows
df.sample()

# Transpose rows and columns
df.T

# Convert DataFrame to NumPy array
df.to_numpy()

# Convert DataFrame to dictionary
df.to_dict()

# Save DataFrame to CSV
df.to_csv()

# Save DataFrame to Excel
df.to_excel()

# Save DataFrame to JSON
df.to_json()
